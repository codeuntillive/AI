# %% [markdown]
# # Random Forest Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# importing data
data=pd.read_csv('Position_Salaries.csv')
x=data.iloc[:,1:-1].values
y=data.iloc[:,-1].values

# %%
# training_the_model
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=10,random_state=0)
regressor.fit(x,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
x_grid=np.arange(min(x),max(x),0.1)
x_grid=x_grid.reshape(len(x_grid),1)
y_pred=regressor.predict(x_grid).reshape(len(x_grid),1)
plt.plot(x_grid,y_pred,color='blue')
plt.scatter(x,y,color='red')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.title('Rondom Forest Regression')
plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_25652\2916350705.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid=np.arange(min(x),max(x),0.1)
